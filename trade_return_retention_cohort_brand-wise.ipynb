# %%
# import
import pandas as pd
import numpy as np
import warnings
import duckdb
import seaborn as sns

# %%
# preferences
warnings.filterwarnings("ignore")

# %%
# damage data
damage_df=pd.read_excel(open('damage_report_2022.xlsx', 'rb'), sheet_name='Material Receving Status Report', header=0, index_col=None, usecols='B, F, L')
qry='''
select ClaimDate claim_date, DistributorCode distrib_code, SKUName material_desc
from damage_df; 
'''
damage_df=duckdb.query(qry).df()
damage_df
# Out:
#        claim_date  distrib_code                             material_desc
# 0      2022-01-01      15508251           HORLICKS HFD MOTHER BIB 24X350G
# 1      2022-01-01      15508251                  HORLICKS HFD STD 720X18G
# 2      2022-01-01      15508251     GLAXOSE D HLTH FOOD DRINK STD 360X25G
# 3      2022-01-01      15508251  HORLICKS HFD JUNOR STAGE-2 SCHET 144X75G
# 4      2022-01-01      15508251             HORLICKS HFD LITE JAR 24X330G
# ...           ...           ...                                       ...
# 627026 2022-12-01      50256050  HORLICKS HFD JUNOR STAGE-2 SCHET 144X75G
# 627027 2022-12-01      50256050    GLUCOMAX D HLTH F DRNK STD BIB 48X200G
# 627028 2022-12-01      50256050    GLUCOMAX D HLTH F DRNK STD BIB 24X400G
# 627029 2022-12-01      50256050  HORLICKS HFD JUNIOR STGE-2 SACHT 720X16G
# 627030 2022-12-01      50256050  HORLICKS HFD MOTHER'S PLS NS BIB 24X350G
#
# [627031 rows x 3 columns]

# %%
# PH data
ph_df=pd.read_excel(open('01. PH2022-10th Jan 23.xlsx', 'rb'), sheet_name='Selling code_Jan 2023', header=0, index_col=None) 
qry='''
select distinct "Pack size desc." pack_desc, "Material Description" material_desc
from ph_df;
'''
ph_df=duckdb.query(qry).df()
ph_df
# Out:
#                                      pack_desc  \
# 0                          DOVE BAR WHITE 100G
# 1     DOVE HAIR RINSE OUT CONDTNR HFR LC 170ML
# 2                       BB TAAZA PB LOOSE 100G
# 3                       BB TAAZA PB LOOSE 400G
# 4                       BB TAAZA PB LOOSE 400G
# ...                                        ...
# 6848     VASELINE LOTION HEALTHY WHTE LC 400ML
# 6849       VASELINE PETROLEUM JELLY PURE 250ML
# 6850        VASELINE BODY PETROLEUM JELLY 50ML
# 6851  VASELINE BODY PETRLUM JELLY (3X9ML+50ML)
# 6852  VASELINE BODY PETRLUM JELLY (3X9ML+50ML)
#
#                                  material_desc
# 0      DOVE SKIN CLNSNG BAR WHITE 140TK 48X90G
# 1     DOVE CONDITIONR HFR DOLCE 290TK 24X170ML
# 2     BB TAAZA BLACK TEA VNDNG_M 55TK 144X100G
# 3             BB TAAZA BLACK TEA T_188 24X400G
# 4             BB TAAZA BLACK TEA T_143 24X400G
# ...                                        ...
# 6848    VASELINE LOTION HLTHY BRT W22 12X400ML
# 6849    VASELINE PETROLEUM JELLY PURE 24X250ML
# 6850  VASELINE PET JLLY ICON 50TK ENT 108X50ML
# 6851  VASELINE PT JLY 7125TKDD 75X(3X9ML+50ML)
# 6852  VASELINE PJ W22 7500T DD 75X(3X9ML+50ML)
#
# [6853 rows x 2 columns]

# %%
# COTC/Premium/MD data
cotc_df=pd.read_excel(open('IOP 2023 - COTC, MD & Premium List - Final.xlsx', 'rb'), sheet_name='COTC, MD & Premium List', header=0, index_col=None) 
qry='''
select distinct upper(SKUs) pack_desc, "Category" cat, "Business Group" bg
from cotc_df
where
    "COTC in 2023?" ilike '%yes%'
    -- or "Premium in 2023?" ilike '%yes%'
    -- or "MD in 2023?" ilike '%yes%';
'''
cotc_df=duckdb.query(qry).df()
cotc_df['brand']=cotc_df['pack_desc'].apply(lambda x: x.split()[0])
cotc_df
# Out:
#                                    pack_desc              cat  \
# 0                       VIM HDW NSD BAR 300G   Home & Hygiene
# 1         SUNSILK SHAMPOO THICK & LONG 375ML        Hair Care
# 2         SUNSILK SHAMPOO THICK & LONG 180ML        Hair Care
# 3         RIN NM STD POWDER POWER WHITE 500G  Fabric Cleaning
# 4     LUX SKIN CLEANSING BAR SOFT TOUCH 150G   Skin Cleansing
# 5       PEPSODENT TOOTHPASTE GERMICHECK 200G        Oral Care
# 6     LIFEBUOY SKIN CLEANSING BAR TOTAL 100G   Skin Cleansing
# 7      LIFEBUOY SKIN CLEANSING BAR CARE 100G   Skin Cleansing
# 8   CLOSE-UP THPSTE FRESHNSS MINT CHILL 100G        Oral Care
# 9    CLOSE-UP THPSTE FRESHNSS MINT CHILL 50G        Oral Care
# 10         VASELINE BODY PETROLEUM JELLY 9ML        Skin Care
# 11                       VIM HDW NSD BAR 70G   Home & Hygiene
# 12   GLOW & LOVELY FACIAL MST MLTVIT CRM 50G        Skin Care
# 13               SUNSILK SHAMPOO BLACK 180ML        Hair Care
# 14                      VIM HDW NSD BAR 100G   Home & Hygiene
# 15       RIN NM STD POWDER POWER WHITE 1000G  Fabric Cleaning
# 16        WHEEL NM STD PWDR CLEN&FRESH 1000G  Fabric Cleaning
# 17  WHEEL NM STD PWDR ACTIVE CLEAN&FRSH 500G  Fabric Cleaning
# 18   LIFEBUOY SKIN CLNG BAR LEMON FRESH 100G   Skin Cleansing
# 19            SUNSILK SHAMPOO THICK&LONG 6ML        Hair Care
# 20                SUNSILK SHAMPOO BLACK 90ML        Hair Care
# 21        WHEEL NM STD PWDR CLEAN&FRESH 500G  Fabric Cleaning
# 22              SURF NM STD POWDER EXCEL 20G  Fabric Cleaning
# 23       PEPSODENT TOOTHPASTE GERMICHECK 45G        Oral Care
# 24   GLOW & LOVELY FACIAL MST MLTVIT CRM 25G        Skin Care
# 25               SUNSILK SHAMPOO BLACK 375ML        Hair Care
# 26      PEPSODENT TOOTHPASTE GERMICHECK 100G        Oral Care
# 27                 SUNSILK SHAMPOO BLACK 6ML        Hair Care
# 28  WHEEL NM STD PWDR ACTIVE CLEN&FRSH 1000G  Fabric Cleaning
# 29    LUX SKIN CLEANSING BAR SOFT TOUCH 100G   Skin Cleansing
# 30  LUX SKIN CLEANSING BAR VELVET TOUCH 150G   Skin Cleansing
# 31  LUX SKIN CLEANSING BAR VELVET TOUCH 100G   Skin Cleansing
# 32  CLOSE-UP THPSTE FRESHNSS MINT CHILL 145G        Oral Care
# 33        VASELINE BODY PETROLEUM JELLY 50ML        Skin Care
#
#                     bg      brand
# 0            Home Care        VIM
# 1   Beauty & Wellbeing    SUNSILK
# 2   Beauty & Wellbeing    SUNSILK
# 3            Home Care        RIN
# 4        Personal Care        LUX
# 5        Personal Care  PEPSODENT
# 6        Personal Care   LIFEBUOY
# 7        Personal Care   LIFEBUOY
# 8        Personal Care   CLOSE-UP
# 9        Personal Care   CLOSE-UP
# 10  Beauty & Wellbeing   VASELINE
# 11           Home Care        VIM
# 12  Beauty & Wellbeing       GLOW
# 13  Beauty & Wellbeing    SUNSILK
# 14           Home Care        VIM
# 15           Home Care        RIN
# 16           Home Care      WHEEL
# 17           Home Care      WHEEL
# 18       Personal Care   LIFEBUOY
# 19  Beauty & Wellbeing    SUNSILK
# 20  Beauty & Wellbeing    SUNSILK
# 21           Home Care      WHEEL
# 22           Home Care       SURF
# 23       Personal Care  PEPSODENT
# 24  Beauty & Wellbeing       GLOW
# 25  Beauty & Wellbeing    SUNSILK
# 26       Personal Care  PEPSODENT
# 27  Beauty & Wellbeing    SUNSILK
# 28           Home Care      WHEEL
# 29       Personal Care        LUX
# 30       Personal Care        LUX
# 31       Personal Care        LUX
# 32       Personal Care   CLOSE-UP
# 33  Beauty & Wellbeing   VASELINE

# %%
# COTC damage data
qry='''
select left(claim_date::text, 7) claim_month, distrib_code, brand
from 
    damage_df tbl1 
    inner join 
    ph_df tbl2 using(material_desc)
    inner join 
    cotc_df tbl3 using(pack_desc);
'''
ret_df=duckdb.query(qry).df()
ret_df
# Out:
#       claim_month  distrib_code      brand
# 0         2022-11      15577322       GLOW
# 1         2022-11      15577322       GLOW
# 2         2022-11      15577322  PEPSODENT
# 3         2022-11      15577322   CLOSE-UP
# 4         2022-11      15577322    SUNSILK
# ...           ...           ...        ...
# 78715     2022-09      15385699       GLOW
# 78716     2022-09      15416099       GLOW
# 78717     2022-09      15416517       GLOW
# 78718     2022-09      15465740       GLOW
# 78719     2022-09      15465740       GLOW
#
# [78720 rows x 3 columns]

# %%
# brands
brands=set(ret_df['brand'])
print(brands)
# Out:
# {'SUNSILK', 'VASELINE', 'PEPSODENT', 'RIN', 'LIFEBUOY', 'VIM', 'GLOW', 'LUX', 'SURF', 'CLOSE-UP', 'WHEEL'}

# %%
# cohort
sku_cohort_num_df=pd.DataFrame()
sku_cohort_pct_df=pd.DataFrame()

for b in brands: 
    qry='''
    with
        cohort as
        (select 
            tbl1.claim_month claim_month_from, 
            tbl2.claim_month claim_month_to, 
            datediff('month', (tbl1.claim_month || '-01')::date, (tbl2.claim_month || '-01')::date) month_diff, 
            count(distinct tbl1.distrib_code) distributors_ret
        from 
            (select claim_month, distrib_code, brand
            from ret_df
            where brand='''+"'"+b+"'"+'''
            ) tbl1 

            left join 

            (select claim_month, distrib_code, brand
            from ret_df
            where brand='''+"'"+b+"'"+'''
            ) tbl2 on(tbl1.distrib_code=tbl2.distrib_code and tbl1.claim_month<=tbl2.claim_month)
        group by 1, 2, 3
        ) 

    select *, distributors_ret*1.00/distributors_init distributors_ret_pct
    from 
        cohort tbl1

        inner join 

        (select claim_month_from, distributors_ret distributors_init
        from cohort
        where month_diff=0
        ) tbl2 using(claim_month_from)
    order by 1, 2; 
    '''
    cohort_df=duckdb.query(qry).df()

    # cohort (number)
    cohort_df_piv=pd.pivot_table(cohort_df, index='claim_month_from', columns='month_diff', values='distributors_ret', aggfunc='sum')
    cohort_df_piv.loc['avg.']=cohort_df_piv.mean(axis=0)
    cohort_df_piv['brand']=b
    sku_cohort_num_df=sku_cohort_num_df._append(cohort_df_piv.tail(1))
    
    # cohort (pct)
    cohort_df_piv=pd.pivot_table(cohort_df, index='claim_month_from', columns='month_diff', values='distributors_ret_pct', aggfunc='sum')
    cohort_df_piv.loc['avg.']=cohort_df_piv.mean(axis=0)
    cohort_df_piv['brand']=b
    sku_cohort_pct_df=sku_cohort_pct_df._append(cohort_df_piv.tail(1))
    
    print("Cohorts generated for brand: "+b)

display(sku_cohort_num_df)
display(sku_cohort_pct_df)
# Out:
# Cohorts generated for brand: SUNSILK
# Cohorts generated for brand: VASELINE
# Cohorts generated for brand: PEPSODENT
# Cohorts generated for brand: RIN
# Cohorts generated for brand: LIFEBUOY
# Cohorts generated for brand: VIM
# Cohorts generated for brand: GLOW
# Cohorts generated for brand: LUX
# Cohorts generated for brand: SURF
# Cohorts generated for brand: CLOSE-UP
# Cohorts generated for brand: WHEEL
# month_diff                 0           1      2           3        4  \
# claim_month_from
# avg.              191.333333  187.454545  186.1  184.666667  183.750
# avg.              142.833333  113.818182  105.4   95.222222   89.125
# avg.              187.916667  180.727273  179.4  178.888889  177.125
# avg.               68.916667   51.636364   49.1   49.888889   49.625
# avg.               90.750000   63.090909   62.4   61.222222   60.000
# avg.               83.833333   57.909091   58.1   58.000000   57.000
# avg.              176.416667  163.272727  161.8  160.777778  159.125
# avg.              108.583333   83.636364   83.7   82.888889   81.375
# avg.               31.750000   17.818182   18.5   17.222222   17.000
# avg.              184.416667  175.272727  173.9  173.111111  171.375
# avg.               68.333333   48.000000   43.7   40.777778   41.750
#
# month_diff                 5           6      7       8           9     10  \
# claim_month_from
# avg.              182.000000  182.000000  180.8  178.50  177.000000  175.5
# avg.               91.857143  105.666667  118.4  129.00  136.000000  134.0
# avg.              175.714286  175.000000  173.4  173.50  172.666667  170.5
# avg.               48.142857   48.166667   46.0   44.25   42.333333   43.0
# avg.               59.428571   60.833333   62.2   58.50   60.333333   56.0
# avg.               56.000000   56.666667   56.0   54.75   56.000000   57.0
# avg.              158.428571  158.666667  157.8  155.00  152.000000  152.0
# avg.               81.714286   80.000000   79.6   78.00   77.666667   76.0
# avg.               16.142857   15.333333   14.4   14.25   14.000000   12.5
# avg.              169.714286  170.333333  168.6  168.75  166.000000  162.5
# avg.               40.428571   40.833333   43.4   44.25   43.000000   45.5
#
# month_diff           11      brand
# claim_month_from
# avg.              173.0    SUNSILK
# avg.              131.0   VASELINE
# avg.              172.0  PEPSODENT
# avg.               41.0        RIN
# avg.               60.0   LIFEBUOY
# avg.               56.0        VIM
# avg.              150.0       GLOW
# avg.               79.0        LUX
# avg.               17.0       SURF
# avg.              162.0   CLOSE-UP
# avg.               41.0      WHEEL
# month_diff          0         1         2         3         4         5  \
# claim_month_from
# avg.              1.0  0.979570  0.972316  0.964577  0.960166  0.951428
# avg.              1.0  0.784991  0.755654  0.706945  0.690323  0.702965
# avg.              1.0  0.962669  0.956271  0.955488  0.947867  0.941968
# avg.              1.0  0.750014  0.716483  0.726182  0.734435  0.730565
# avg.              1.0  0.693583  0.684087  0.678541  0.660675  0.661945
# avg.              1.0  0.690438  0.702543  0.694861  0.680249  0.669847
# avg.              1.0  0.923838  0.911594  0.901614  0.893260  0.887713
# avg.              1.0  0.772893  0.773177  0.764822  0.744855  0.755105
# avg.              1.0  0.567470  0.579636  0.530444  0.522468  0.506016
# avg.              1.0  0.952017  0.947721  0.945380  0.939466  0.931785
# avg.              1.0  0.713692  0.661816  0.614816  0.641228  0.620135
#
# month_diff               6         7         8         9        10        11  \
# claim_month_from
# avg.              0.949533  0.941665  0.930893  0.923482  0.918848  0.905759
# avg.              0.778310  0.767455  0.762387  0.766614  0.731634  0.700535
# avg.              0.941672  0.930300  0.930363  0.926795  0.911896  0.900524
# avg.              0.734426  0.717736  0.695287  0.669069  0.674089  0.672131
# avg.              0.667057  0.673788  0.623160  0.634741  0.591837  0.612245
# avg.              0.670919  0.658150  0.624680  0.638129  0.655478  0.571429
# avg.              0.887119  0.876646  0.856501  0.839831  0.842117  0.837989
# avg.              0.734030  0.733108  0.704049  0.710011  0.698860  0.686957
# avg.              0.477884  0.454013  0.466667  0.457348  0.409677  0.566667
# avg.              0.940130  0.925184  0.924640  0.918893  0.910405  0.900000
# avg.              0.612554  0.633813  0.608109  0.523804  0.552922  0.525641
#
# month_diff            brand
# claim_month_from
# avg.                SUNSILK
# avg.               VASELINE
# avg.              PEPSODENT
# avg.                    RIN
# avg.               LIFEBUOY
# avg.                    VIM
# avg.                   GLOW
# avg.                    LUX
# avg.                   SURF
# avg.               CLOSE-UP
# avg.                  WHEEL

# %%
# style
cm=sns.color_palette("blend:white,blue", as_cmap=True)
cm.set_bad("white")

# %%
# show pct cohort
df=sku_cohort_pct_df
cols=list(df.columns)
cols=[cols[-1]]+cols[:-1]
df=df[cols].reset_index(drop=True)
df.style.format(formatter="{:.2%}", subset=df.select_dtypes(include=np.number).columns.tolist()).background_gradient(cmap=cm, axis=None, low=0.1, high=1.0).hide()
# Out:
# <style type="text/css">
# #T_641b1_row0_col1, #T_641b1_row1_col1, #T_641b1_row2_col1, #T_641b1_row3_col1, #T_641b1_row4_col1, #T_641b1_row5_col1, #T_641b1_row6_col1, #T_641b1_row7_col1, #T_641b1_row8_col1, #T_641b1_row9_col1, #T_641b1_row10_col1 {
#   background-color: #7979ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col2 {
#   background-color: #7e7eff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col3 {
#   background-color: #7f7fff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col4, #T_641b1_row2_col2 {
#   background-color: #8181ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col5, #T_641b1_row2_col3 {
#   background-color: #8282ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col6, #T_641b1_row2_col4, #T_641b1_row9_col2 {
#   background-color: #8383ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col7, #T_641b1_row2_col5, #T_641b1_row9_col3 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col8, #T_641b1_row2_col6, #T_641b1_row2_col7, #T_641b1_row9_col4 {
#   background-color: #8585ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col9, #T_641b1_row2_col8, #T_641b1_row2_col9 {
#   background-color: #8888ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col10, #T_641b1_row2_col10, #T_641b1_row6_col2, #T_641b1_row9_col8, #T_641b1_row9_col9 {
#   background-color: #8989ff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col11, #T_641b1_row9_col10 {
#   background-color: #8a8aff;
#   color: #f1f1f1;
# }
# #T_641b1_row0_col12 {
#   background-color: #8d8dff;
#   color: #f1f1f1;
# }
# #T_641b1_row1_col2 {
#   background-color: #a6a6ff;
#   color: #000000;
# }
# #T_641b1_row1_col3, #T_641b1_row7_col6 {
#   background-color: #acacff;
#   color: #000000;
# }
# #T_641b1_row1_col4 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_641b1_row1_col5, #T_641b1_row4_col2, #T_641b1_row5_col2 {
#   background-color: #b9b9ff;
#   color: #000000;
# }
# #T_641b1_row1_col6, #T_641b1_row1_col12, #T_641b1_row5_col3, #T_641b1_row7_col9 {
#   background-color: #b7b7ff;
#   color: #000000;
# }
# #T_641b1_row1_col7 {
#   background-color: #a7a7ff;
#   color: #000000;
# }
# #T_641b1_row1_col8 {
#   background-color: #a9a9ff;
#   color: #000000;
# }
# #T_641b1_row1_col9, #T_641b1_row1_col10, #T_641b1_row7_col4 {
#   background-color: #aaaaff;
#   color: #000000;
# }
# #T_641b1_row1_col11, #T_641b1_row3_col6, #T_641b1_row7_col8 {
#   background-color: #b1b1ff;
#   color: #000000;
# }
# #T_641b1_row2_col11, #T_641b1_row6_col3, #T_641b1_row9_col11 {
#   background-color: #8c8cff;
#   color: #f1f1f1;
# }
# #T_641b1_row2_col12, #T_641b1_row6_col4, #T_641b1_row9_col12 {
#   background-color: #8e8eff;
#   color: #f1f1f1;
# }
# #T_641b1_row3_col2 {
#   background-color: #adadff;
#   color: #000000;
# }
# #T_641b1_row3_col3, #T_641b1_row3_col8 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_641b1_row3_col4 {
#   background-color: #b2b2ff;
#   color: #000000;
# }
# #T_641b1_row3_col5, #T_641b1_row3_col7, #T_641b1_row7_col7 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_641b1_row3_col9, #T_641b1_row5_col4, #T_641b1_row7_col11 {
#   background-color: #b8b8ff;
#   color: #000000;
# }
# #T_641b1_row3_col10, #T_641b1_row4_col7, #T_641b1_row5_col6 {
#   background-color: #bebeff;
#   color: #000000;
# }
# #T_641b1_row3_col11, #T_641b1_row3_col12, #T_641b1_row4_col8, #T_641b1_row5_col7 {
#   background-color: #bdbdff;
#   color: #000000;
# }
# #T_641b1_row4_col3, #T_641b1_row5_col5 {
#   background-color: #bbbbff;
#   color: #000000;
# }
# #T_641b1_row4_col4 {
#   background-color: #bcbcff;
#   color: #000000;
# }
# #T_641b1_row4_col5, #T_641b1_row4_col6, #T_641b1_row10_col3 {
#   background-color: #bfbfff;
#   color: #000000;
# }
# #T_641b1_row4_col9, #T_641b1_row5_col9 {
#   background-color: #c7c7ff;
#   color: #000000;
# }
# #T_641b1_row4_col10, #T_641b1_row10_col8 {
#   background-color: #c5c5ff;
#   color: #000000;
# }
# #T_641b1_row4_col11 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_641b1_row4_col12, #T_641b1_row10_col4, #T_641b1_row10_col7 {
#   background-color: #c9c9ff;
#   color: #000000;
# }
# #T_641b1_row5_col8 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_641b1_row5_col10 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_641b1_row5_col11 {
#   background-color: #c1c1ff;
#   color: #000000;
# }
# #T_641b1_row5_col12 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_641b1_row6_col5 {
#   background-color: #8f8fff;
#   color: #f1f1f1;
# }
# #T_641b1_row6_col6, #T_641b1_row6_col7 {
#   background-color: #9191ff;
#   color: #f1f1f1;
# }
# #T_641b1_row6_col8 {
#   background-color: #9393ff;
#   color: #f1f1f1;
# }
# #T_641b1_row6_col9 {
#   background-color: #9797ff;
#   color: #f1f1f1;
# }
# #T_641b1_row6_col10, #T_641b1_row6_col11 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_641b1_row6_col12 {
#   background-color: #9b9bff;
#   color: #f1f1f1;
# }
# #T_641b1_row7_col2, #T_641b1_row7_col3 {
#   background-color: #a8a8ff;
#   color: #000000;
# }
# #T_641b1_row7_col5 {
#   background-color: #aeaeff;
#   color: #000000;
# }
# #T_641b1_row7_col10, #T_641b1_row10_col2 {
#   background-color: #b5b5ff;
#   color: #000000;
# }
# #T_641b1_row7_col12 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_641b1_row8_col2, #T_641b1_row8_col12 {
#   background-color: #d3d3ff;
#   color: #000000;
# }
# #T_641b1_row8_col3 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_641b1_row8_col4 {
#   background-color: #dadaff;
#   color: #000000;
# }
# #T_641b1_row8_col5, #T_641b1_row10_col10 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_641b1_row8_col6 {
#   background-color: #dfdfff;
#   color: #000000;
# }
# #T_641b1_row8_col7 {
#   background-color: #e5e5ff;
#   color: #000000;
# }
# #T_641b1_row8_col8 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_641b1_row8_col9 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_641b1_row8_col10 {
#   background-color: #e9e9ff;
#   color: #000000;
# }
# #T_641b1_row8_col11 {
#   background-color: #f3f3ff;
#   color: #000000;
# }
# #T_641b1_row9_col5, #T_641b1_row9_col7 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_641b1_row9_col6 {
#   background-color: #8787ff;
#   color: #f1f1f1;
# }
# #T_641b1_row10_col5 {
#   background-color: #c3c3ff;
#   color: #000000;
# }
# #T_641b1_row10_col6 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_641b1_row10_col9 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_641b1_row10_col11 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_641b1_row10_col12 {
#   background-color: #dbdbff;
#   color: #000000;
# }
# </style>
# <table id="T_641b1">
#   <thead>
#     <tr>
#       <th id="T_641b1_level0_col0" class="col_heading level0 col0" >brand</th>
#       <th id="T_641b1_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_641b1_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_641b1_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_641b1_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_641b1_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_641b1_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_641b1_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_641b1_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_641b1_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_641b1_level0_col10" class="col_heading level0 col10" >9</th>
#       <th id="T_641b1_level0_col11" class="col_heading level0 col11" >10</th>
#       <th id="T_641b1_level0_col12" class="col_heading level0 col12" >11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_641b1_row0_col0" class="data row0 col0" >SUNSILK</td>
#       <td id="T_641b1_row0_col1" class="data row0 col1" >100.00%</td>
#       <td id="T_641b1_row0_col2" class="data row0 col2" >97.96%</td>
#       <td id="T_641b1_row0_col3" class="data row0 col3" >97.23%</td>
#       <td id="T_641b1_row0_col4" class="data row0 col4" >96.46%</td>
#       <td id="T_641b1_row0_col5" class="data row0 col5" >96.02%</td>
#       <td id="T_641b1_row0_col6" class="data row0 col6" >95.14%</td>
#       <td id="T_641b1_row0_col7" class="data row0 col7" >94.95%</td>
#       <td id="T_641b1_row0_col8" class="data row0 col8" >94.17%</td>
#       <td id="T_641b1_row0_col9" class="data row0 col9" >93.09%</td>
#       <td id="T_641b1_row0_col10" class="data row0 col10" >92.35%</td>
#       <td id="T_641b1_row0_col11" class="data row0 c

# %%
# show num cohort
df=sku_cohort_num_df
cols=list(df.columns)
cols=[cols[-1]]+cols[:-1]
df=df[cols].reset_index(drop=True)
df.style.format(formatter="{:.2f}", subset=df.select_dtypes(include=np.number).columns.tolist()).background_gradient(cmap=cm, axis=None, low=0.1, high=1.0).hide()
# Out:
# <style type="text/css">
# #T_94ac5_row0_col1 {
#   background-color: #7979ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col2, #T_94ac5_row2_col1 {
#   background-color: #7c7cff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col3 {
#   background-color: #7d7dff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col4, #T_94ac5_row9_col1 {
#   background-color: #7e7eff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col5 {
#   background-color: #7f7fff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col6, #T_94ac5_row0_col7 {
#   background-color: #8080ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col8, #T_94ac5_row2_col2 {
#   background-color: #8181ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col9, #T_94ac5_row2_col3, #T_94ac5_row2_col4 {
#   background-color: #8282ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col10, #T_94ac5_row2_col5 {
#   background-color: #8383ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col11, #T_94ac5_row2_col6, #T_94ac5_row6_col1, #T_94ac5_row9_col2 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row0_col12, #T_94ac5_row2_col8, #T_94ac5_row2_col9, #T_94ac5_row2_col10, #T_94ac5_row9_col4 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row1_col1 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_94ac5_row1_col2 {
#   background-color: #aeaeff;
#   color: #000000;
# }
# #T_94ac5_row1_col3, #T_94ac5_row1_col7 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_94ac5_row1_col4 {
#   background-color: #bbbbff;
#   color: #000000;
# }
# #T_94ac5_row1_col5 {
#   background-color: #bfbfff;
#   color: #000000;
# }
# #T_94ac5_row1_col6 {
#   background-color: #bdbdff;
#   color: #000000;
# }
# #T_94ac5_row1_col8 {
#   background-color: #ababff;
#   color: #000000;
# }
# #T_94ac5_row1_col9 {
#   background-color: #a4a4ff;
#   color: #000000;
# }
# #T_94ac5_row1_col10 {
#   background-color: #9f9fff;
#   color: #f1f1f1;
# }
# #T_94ac5_row1_col11 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row1_col12 {
#   background-color: #a3a3ff;
#   color: #000000;
# }
# #T_94ac5_row2_col7, #T_94ac5_row9_col3 {
#   background-color: #8585ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row2_col11, #T_94ac5_row9_col6, #T_94ac5_row9_col7 {
#   background-color: #8888ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row2_col12, #T_94ac5_row9_col5 {
#   background-color: #8787ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row3_col1, #T_94ac5_row10_col1 {
#   background-color: #cdcdff;
#   color: #000000;
# }
# #T_94ac5_row3_col2 {
#   background-color: #d9d9ff;
#   color: #000000;
# }
# #T_94ac5_row3_col3, #T_94ac5_row3_col4, #T_94ac5_row3_col5 {
#   background-color: #dadaff;
#   color: #000000;
# }
# #T_94ac5_row3_col6, #T_94ac5_row3_col7, #T_94ac5_row10_col2 {
#   background-color: #dbdbff;
#   color: #000000;
# }
# #T_94ac5_row3_col8 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_94ac5_row3_col9, #T_94ac5_row10_col3, #T_94ac5_row10_col8, #T_94ac5_row10_col9 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_94ac5_row3_col10, #T_94ac5_row3_col11, #T_94ac5_row10_col5, #T_94ac5_row10_col10 {
#   background-color: #dfdfff;
#   color: #000000;
# }
# #T_94ac5_row3_col12, #T_94ac5_row10_col4, #T_94ac5_row10_col6, #T_94ac5_row10_col7, #T_94ac5_row10_col12 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_94ac5_row4_col1 {
#   background-color: #bebeff;
#   color: #000000;
# }
# #T_94ac5_row4_col2, #T_94ac5_row4_col3, #T_94ac5_row4_col8 {
#   background-color: #d1d1ff;
#   color: #000000;
# }
# #T_94ac5_row4_col4, #T_94ac5_row4_col7 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_94ac5_row4_col5, #T_94ac5_row4_col6, #T_94ac5_row4_col10, #T_94ac5_row4_col12 {
#   background-color: #d3d3ff;
#   color: #000000;
# }
# #T_94ac5_row4_col9, #T_94ac5_row5_col2, #T_94ac5_row5_col3, #T_94ac5_row5_col4 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_94ac5_row4_col11, #T_94ac5_row5_col6, #T_94ac5_row5_col8, #T_94ac5_row5_col10, #T_94ac5_row5_col12 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_94ac5_row5_col1, #T_94ac5_row7_col2, #T_94ac5_row7_col3, #T_94ac5_row7_col4 {
#   background-color: #c3c3ff;
#   color: #000000;
# }
# #T_94ac5_row5_col5, #T_94ac5_row5_col7, #T_94ac5_row5_col11 {
#   background-color: #d5d5ff;
#   color: #000000;
# }
# #T_94ac5_row5_col9 {
#   background-color: #d7d7ff;
#   color: #000000;
# }
# #T_94ac5_row6_col2, #T_94ac5_row9_col11, #T_94ac5_row9_col12 {
#   background-color: #8d8dff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col3, #T_94ac5_row6_col4 {
#   background-color: #8e8eff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col5 {
#   background-color: #8f8fff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col6, #T_94ac5_row6_col7, #T_94ac5_row6_col8 {
#   background-color: #9090ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col9 {
#   background-color: #9292ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col10, #T_94ac5_row6_col11 {
#   background-color: #9494ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row6_col12 {
#   background-color: #9696ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row7_col1 {
#   background-color: #b2b2ff;
#   color: #000000;
# }
# #T_94ac5_row7_col5, #T_94ac5_row7_col6 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_94ac5_row7_col7 {
#   background-color: #c5c5ff;
#   color: #000000;
# }
# #T_94ac5_row7_col8, #T_94ac5_row7_col12 {
#   background-color: #c6c6ff;
#   color: #000000;
# }
# #T_94ac5_row7_col9, #T_94ac5_row7_col10 {
#   background-color: #c7c7ff;
#   color: #000000;
# }
# #T_94ac5_row7_col11 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_94ac5_row8_col1 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_94ac5_row8_col2, #T_94ac5_row8_col4, #T_94ac5_row8_col5, #T_94ac5_row8_col12 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_94ac5_row8_col3 {
#   background-color: #efefff;
#   color: #000000;
# }
# #T_94ac5_row8_col6, #T_94ac5_row8_col7 {
#   background-color: #f1f1ff;
#   color: #000000;
# }
# #T_94ac5_row8_col8, #T_94ac5_row8_col9, #T_94ac5_row8_col10 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_94ac5_row8_col11 {
#   background-color: #f3f3ff;
#   color: #000000;
# }
# #T_94ac5_row9_col8, #T_94ac5_row9_col9 {
#   background-color: #8989ff;
#   color: #f1f1f1;
# }
# #T_94ac5_row9_col10 {
#   background-color: #8b8bff;
#   color: #f1f1f1;
# }
# #T_94ac5_row10_col11 {
#   background-color: #ddddff;
#   color: #000000;
# }
# </style>
# <table id="T_94ac5">
#   <thead>
#     <tr>
#       <th id="T_94ac5_level0_col0" class="col_heading level0 col0" >brand</th>
#       <th id="T_94ac5_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_94ac5_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_94ac5_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_94ac5_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_94ac5_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_94ac5_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_94ac5_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_94ac5_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_94ac5_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_94ac5_level0_col10" class="col_heading level0 col10" >9</th>
#       <th id="T_94ac5_level0_col11" class="col_heading level0 col11" >10</th>
#       <th id="T_94ac5_level0_col12" class="col_heading level0 col12" >11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94ac5_row0_col0" class="data row0 col0" >SUNSILK</td>
#       <td id="T_94ac5_row0_col1" class="data row0 col1" >191.33</td>
#       <td id="T_94ac5_row0_col2" class="data row0 col2" >187.45</td>
#       <td id="T_94ac5_row0_col3" class="data row0 col3" >186.10</td>
#       <td id="T_94ac5_row0_col4" class="data row0 col4" >184.67</td>
#       <td id="T_94ac5_row0_col5" class="data row0 col5" >183.75</td>
#       <td id="T_94ac5_row0_col6" class="data row0 col6" >182.00</td>
#       <td id="T_94ac5_row0_col7" class="data row0 col7" >182.00</td>
#       <td id="T_94ac5_row0_col8" class="data row0 col8" >180.80</td>
#       <td id="T_94ac5_row0_col9" class="data row0 col9" >178.50</td>
#       <td id="T_94ac5_row0_col10" class="data row0 col10" >177.00</td>
#       <td id="T_94ac5_row0_col11" class="data row0 col11" >175.50</td>
#       <td id="T_94ac5_row0_col12" class="data row0 col12" >173.00</td>
#     </tr>
#     <tr>
#       <td id="T_94ac5_row1_col0" class="data row1 col0" >VASELINE</td>
#       <td id="T_94ac5
